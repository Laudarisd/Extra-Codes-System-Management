# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns



df1 = pd.read_csv('./csv/23.csv')
print(df1.shape)

plt.figure(figsize=(10, 8))
sns.scatterplot(x='x', y='z', data=df1, hue='radius', s=100, palette='rainbow')
plt.show()
# Out:
# (258603, 21)
