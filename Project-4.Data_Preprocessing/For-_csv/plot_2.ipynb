# %%
import csv

# %%
import csv
import operator
import glob
import pandas as pd

data = dict() # filename : lists

path="./result/2021_04_16.csv"
files=glob.glob(path)
for filename in files:
    df = pd.read_csv(filename)
    df.sort_values('ratio(B/A)', inplace=True)
    df.to_csv('./result/plot.csv', index=False)

# %%
import csv
import operator
import glob
import pandas as pd

df = pd.read_csv("./result/plot.csv")
df.head()
# Out:
#    radius(%)     A_r    B_r  ratio(A/B)  ratio(B/A)  Accuracy%
# 0         50  0.0120  0.008       1.500    0.666667       0.94
# 1         40  0.0112  0.008       1.400    0.714286       0.93
# 2         33  0.0120  0.009       1.333    0.750000       0.91
# 3         20  0.0120  0.010       1.200    0.833333       0.83
# 4         10  0.0110  0.010       1.100    0.909091       0.61

# %%
import seaborn as sns
#sns.set()
#sns.scatterplot(df['ratio'], df['Accuracy%'])

sns_plot = sns.pairplot(df, hue='ratio(B/A)')
plt.savefig('all.png')
# Out:
# /home/vision/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/vision/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/vision/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/vision/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/vision/.local/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
data = pd.read_csv("./result/plot.csv")
info = data.iloc[0:]
sns.lineplot(x = "ratio(B/A)", y = "Accuracy%", data=info, hue="ratio(B/A)")
plt.show()

# %%
sns.lineplot(data=df)

# %%
#%matplotlib
import matplotlib.pyplot as plt
df.plot(x="ratio(A/B)", y=["Accuracy%"])
plt.show()
plt.savefig("./result/ratio_accuracy.png")

# %%
with open('./result/plot.csv',"r") as f:
    reader = csv.DictReader(f)
    data = {}
    for row in reader:
        for header, value in row.items():
            try:
                data[header].append(value)
            except KeyError:
                data[header] = [value]
ratio = data['ratio']
accu = data['Accuracy%']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-3f7d6f1bb126> in <module>
#       8             except KeyError:
#       9                 data[header] = [value]
# ---> 10 ratio = data['ratio']
#      11 accu = data['Accuracy%']
#
# KeyError: 'ratio'

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({ "ratio %" : [1, 2,5,10,20,30,33,40,50],
                   "accu" : [0.48,0.47,0.50,0.67,0.85,0.90,0.90,0.91,0.94],
                    "ratio" : [1.010, 1.020,1.050,1.100,1.200,1.333,1.333,1.400,1.500]
                   })
df.plot(x="ratio %", y=["accu", "ratio"])
plt.show()

# %%
df = pd.read_csv('./result/plot.csv')
plt.plot(df['ratio(A/B)'],df['Accuracy%'], 'o', label='plot', color='green')
plt.xlabel('ratio')
plt.ylabel("Accuracy")
plt.title('visualization') 
plt.grid(False)
plt.legend()
#plt.savefig("one_time.png")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
